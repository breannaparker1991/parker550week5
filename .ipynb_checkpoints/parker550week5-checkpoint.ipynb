# %%
#all of my imports 
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import re
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score
from sklearn import datasets, svm
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
#load data
df = pd.read_csv('review.tsv', header=0, delimiter='\t', quoting=3)

# %%
# Print the shape
print(df.shape)
# Out:
# (25000, 3)

# %%
#print data frame
print(df.head())
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %% [markdown]
# Get the stemmed data using the same process you did in Week 3.

# %%
#stemming the data

corpus = []
for i in range(df.shape[0]):
    # Remove HTML tags and characters
    review = re.sub('[^a-zA-Z]', ' ', df['review'][i])
    review = re.sub('<[^>]*>', '', review)
    # Convert to lowercase
    review = review.lower().split()
    # Remove stop words and stem words
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# Print the stemmed corpus
print(corpus[:2])
# Out:
# ['stuff go moment mj start listen music watch odd documentari watch wiz watch moonwalk mayb want get certain insight guy thought realli cool eighti mayb make mind whether guilti innoc moonwalk part biographi part featur film rememb go see cinema origin releas subtl messag mj feel toward press also obviou messag drug bad kay br br visual impress cours michael jackson unless remot like mj anyway go hate find bore may call mj egotist consent make movi mj fan would say made fan true realli nice br br actual featur film bit final start minut exclud smooth crimin sequenc joe pesci convinc psychopath power drug lord want mj dead bad beyond mj overheard plan nah joe pesci charact rant want peopl know suppli drug etc dunno mayb hate mj music br br lot cool thing like mj turn car robot whole speed demon sequenc also director must patienc saint came film kiddi bad sequenc usual director hate work one kid let alon whole bunch perform complex danc scene br br bottom line movi peopl like mj one le
# ...

# %% [markdown]
# Split this into a training and test set.

# %%
# Split the data into training and test sets with 20/80 split
x_train, x_test, y_train, y_test = train_test_split(corpus, df['sentiment'], test_size=0.2, random_state=0)

# %% [markdown]
# Fit and apply the tf-idf vectorization to the training set.

# %%
#applying the tfidf vecotrizer to training set
tfidf = TfidfVectorizer()
x_train_tfidf = tfidf.fit_transform(x_train)

# %% [markdown]
# Apply but DO NOT FIT the tf-idf vectorization to the test set (Why?).

# %%
# Apply the TfidfVectorizer to the test set
x_test_tfidf = tfidf.transform(x_test)

# %% [markdown]
# Train a logistic regression using the training data.

# %%
#running the logistics regression
log_reg = LogisticRegression(C=1.0)

# %%
model = log_reg.fit(x_train_tfidf, y_train)

# %% [markdown]
# Find the model accuracy on the test set.

# %%
#cross validate model using accuracy
cross_val_score(log_reg, x_test_tfidf, y_test, scoring='accuracy' )
# Out:
# array([0.876, 0.865, 0.871, 0.866, 0.864])

# %%
pred = model.predict(x_test_tfidf)
pred
# Out:
# array([1, 1, 1, ..., 1, 0, 1], dtype=int64)

# %%
y_test
# Out:
# 14149    0
# 8946     1
# 22378    0
# 12162    0
# 4879     0
#         ..
# 4022     1
# 17601    1
# 4718     1
# 9376     0
# 8019     1
# Name: sentiment, Length: 5000, dtype: int64

# %%
#accuracy (0.89!!)
print(metrics.accuracy_score(y_test,pred))
# Out:
# 0.8928

# %%
#found a second way to code the accuracy. same result
accuracy = accuracy_score(y_test, pred)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.892800

# %% [markdown]
# Create a confusion matrix for the test set predictions.

# %%
#confusion matrix! 
print(confusion_matrix(y_test,pred))
# Out:
# [[2242  306]
#  [ 230 2222]]

# %% [markdown]
# Get the precision, recall, and F1-score for the test set predictions.

# %%
#cross validate model using precision
cross_val_score(log_reg, x_test_tfidf, y_test, scoring='precision')
# Out:
# array([0.86309524, 0.84872299, 0.86027944, 0.84526112, 0.85571142])

# %%
#cross_validate model using recall
cross_val_score(log_reg, x_test_tfidf, y_test, scoring='recall')
# Out:
# array([0.8877551 , 0.88163265, 0.87959184, 0.89002037, 0.86965377])

# %%
#cross_validate model using F1
cross_val_score(log_reg, x_test_tfidf, y_test, scoring='f1')
# Out:
# array([0.87525151, 0.86486486, 0.86982846, 0.86706349, 0.86262626])

# %%
# precision: tp / (tp + fp)
precision = precision_score(y_test, pred)
print('Precision: %f' % precision)
# Out:
# Precision: 0.878956

# %%
# recall: tp / (tp + fn)
recall = recall_score(y_test, pred)
print('Recall: %f' % recall)
# Out:
# Recall: 0.906199

# %%
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, pred)
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.892369

# %% [markdown]
# Create a ROC curve for the test set.

# %%
#get predicted probabilities 
target_prob = log_reg.predict_proba(x_test_tfidf)[:,1]
target_prob
# Out:
# array([0.74159805, 0.8313835 , 0.74181721, ..., 0.67470336, 0.08109987,
#        0.87123293])

# %%
# ROC accuracy
auc = roc_auc_score(y_test, target_prob)
print('ROC AUC: %f' % auc)
# Out:
# ROC AUC: 0.957262

# %%
#create true and false positive rates
f_pos_rate, t_pos_rate, threshold = roc_curve(y_test, target_prob)

# %%
#plot ROC curve
plt.title("ROC")
plt.plot(f_pos_rate, t_pos_rate)
plt.plot([0,1], ls="--")
plt.plot([0,0], [1,0], c = '.7'), plt.plot([1,1], c = '.7')
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %% [markdown]
# Pick another classification model you learned about this week and repeat steps (5) – (9).

# %% [markdown]
# Train a logistic regression using the training data.

# %%
train_tree = DecisionTreeClassifier(criterion = 'gini', max_depth = 3, random_state = 0)

# %%
train_tree.fit(x_train_tfidf, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
y_pred_tree = train_tree.predict(x_test_tfidf)

# %% [markdown]
# Find the model accuracy on the test set.

# %%
#accuracy (only 0.6844???)
print(accuracy_score(y_test,y_pred_tree))
# Out:
# 0.6844

# %% [markdown]
# Create a confusion matrix for the test set predictions.

# %%
#confusion matrix (very high flase positive and negatives...)
print(confusion_matrix(y_test,y_pred_tree))
# Out:
# [[1282 1266]
#  [ 312 2140]]

# %% [markdown]
# Get the precision, recall, and F1-score for the test set predictions.

# %%
# precision: tp / (tp + fp)
precision = precision_score(y_test, y_pred_tree)
print('Precision: %f' % precision)
# Out:
# Precision: 0.628303

# %%
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred_tree)
print('Recall: %f' % recall)
# Out:
# Recall: 0.872757

# %%
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred_tree)
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.730625

# %% [markdown]
# Create a ROC curve for the test set.

# %%
#get predicted probablities (this is going to be the same for this model because I'm still using the tfidf data.. is that okay?)
target_prob = log_reg.predict_proba(x_test_tfidf)[:,1]
target_prob
# Out:
# array([0.74159805, 0.8313835 , 0.74181721, ..., 0.67470336, 0.08109987,
#        0.87123293])

# %%
#create true and false positive rates
f_pos_rate, t_pos_rate, threshold = roc_curve(y_test, target_prob)

# %%
#plot ROC curve
plt.title("ROC")
plt.plot(f_pos_rate, t_pos_rate)
plt.plot([0,1], ls="--")
plt.plot([0,0], [1,0], c = '.7'), plt.plot([1,1], c = '.7')
plt.ylabel("True Positive Rate")
plt.xlabel("False Positive Rate")
plt.show()

# %%
#visualization of the decision tree
plt.figure(figsize=(15,10))
tree.plot_tree(train_tree.fit(x_train_tfidf,y_train))
# Out:
# [Text(0.5, 0.875, 'x[2637] <= 0.024\ngini = 0.5\nsamples = 20000\nvalue = [9952, 10048]'),
#  Text(0.25, 0.625, 'x[44392] <= 0.011\ngini = 0.489\nsamples = 15704\nvalue = [6673, 9031]'),
#  Text(0.125, 0.375, 'x[43441] <= 0.027\ngini = 0.477\nsamples = 14674\nvalue = [5778, 8896]'),
#  Text(0.0625, 0.125, 'gini = 0.465\nsamples = 13902\nvalue = [5105, 8797]'),
#  Text(0.1875, 0.125, 'gini = 0.224\nsamples = 772\nvalue = [673, 99]'),
#  Text(0.375, 0.375, 'x[44392] <= 0.053\ngini = 0.228\nsamples = 1030\nvalue = [895, 135]'),
#  Text(0.3125, 0.125, 'gini = 0.392\nsamples = 292\nvalue = [214, 78]'),
#  Text(0.4375, 0.125, 'gini = 0.143\nsamples = 738\nvalue = [681, 57]'),
#  Text(0.75, 0.625, 'x[16304] <= 0.021\ngini = 0.361\nsamples = 4296\nvalue = [3279, 1017]'),
#  Text(0.625, 0.375, 'x[2637] <= 0.057\ngini = 0.309\nsamples = 3389\nvalue = [2743, 646]'),
#  Text(0.5625, 0.125, 'gini = 0.39\nsamples = 1550\nvalue = [1139, 411]'),
# ...
